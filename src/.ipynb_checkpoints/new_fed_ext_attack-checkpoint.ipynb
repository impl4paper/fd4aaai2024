# %%
import os
import copy
import time
import pickle
import numpy as np
import pandas as pd
from datetime import datetime
import time
import argparse
import random
import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset, Subset, random_split
from torchvision import datasets, transforms
import torchvision
from torch.autograd import Variable
from torchvision.datasets import MNIST, EMNIST
import torch.nn.functional as F
from matplotlib.pyplot import subplots
from torchvision.utils import save_image
import torch.optim as optim
seed = 42
np.random.seed(seed)
random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
bs = 20
n_epoch = 200
dim=100
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
gpu = 1

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))])

train_dataset = datasets.MNIST(root='../data', train=True, transform=transform, download=True)
test_dataset = datasets.MNIST(root='../data', train=False, transform=transform, download=False)

# Data Loader (Input Pipeline)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=bs, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=100, shuffle=False)

# %%
def test_inference(net, testloader):
    """ Returns the test accuracy and loss.
    """
    net.eval()
    loss, total, correct = 0.0, 0.0, 0.0
    criterion = nn.CrossEntropyLoss()
    criterion.cuda(gpu)
   
    with torch.no_grad():
        for batch_idx, (images, labels) in enumerate(testloader):
            images, labels = images.cuda(gpu), labels.cuda(gpu)

            # Inference
            outputs = net(images)
            batch_loss = criterion(outputs, labels)
            loss += copy.deepcopy(batch_loss.item())

            # Prediction
            _, pred_labels = torch.max(outputs, 1)
            pred_labels = pred_labels.view(-1)
            correct += torch.sum(torch.eq(pred_labels, labels)).item()
            total += len(labels)
    accuracy = correct/total
    return accuracy, loss

def test_error(model, steal_model, testloader):
    model.eval()
    steal_model.eval()
    loss, total, correct = 0.0, 0.0, 0.0
    
    with torch.no_grad():
        for batch_idx, (images, labels) in enumerate(testloader):
            images, labels = images.cuda(gpu), labels.cuda(gpu)

            # Inference
            outputs0 = model(images)
            outputs1 = steal_model(images)
            
            # Prediction
            _, pred_labels0 = torch.max(outputs0, 1)
            pred_labels0 = pred_labels0.view(-1)
            
            _, pred_labels1 = torch.max(outputs1, 1)
            pred_labels1 = pred_labels1.view(-1)
            
            correct += torch.sum(torch.eq(pred_labels0, pred_labels1)).item()
            total += len(labels)
    accuracy = correct/total
    return accuracy

# %%
class Net(nn.Module):
    def __init__(self, dim_in=28*28, dim_hidden=512, dim_out=10):
        super(Net, self).__init__()
        self.layer_input = nn.Linear(dim_in, dim_hidden)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout()
        self.layer_hidden = nn.Linear(dim_hidden, dim_out)

    def forward(self, x):
        x = x.view(-1, x.shape[1]*x.shape[-2]*x.shape[-1])
        x = self.layer_input(x)
        x = self.dropout(x)
        x = self.relu(x)
        x = self.layer_hidden(x)
        return x

# %%
labels = train_dataset.train_labels
pri_indices, pub_indices = [], []
for i in range(0, 6):
    pub_indices += (labels == i).nonzero().view(-1).tolist()
for i in range(7, 9):
    pri_indices += (labels == i).nonzero().view(-1).tolist()
pub_data = Subset(train_dataset, pub_indices)
pub_train_loader = torch.utils.data.DataLoader(pub_data, batch_size=bs,shuffle=True)
pri_data = Subset(train_dataset, pri_indices)
pri_train_loader = torch.utils.data.DataLoader(pri_data, batch_size=bs,shuffle=True)

# %%
global_ep = 200
local_ep = 5
mnist_dim = train_dataset.train_data.size(1) * train_dataset.train_data.size(2)

criterion = nn.CrossEntropyLoss().cuda(gpu)
local_model = Net()
local_model.cuda(gpu)
clone_model = Net()
clone_model.cuda(gpu)
target_accs = []
accs = []
errors = []
local_optimizer = torch.optim.Adam(local_model.parameters())
clone_optimizer = torch.optim.Adam(clone_model.parameters())

for epoch in range(global_ep):
    local_model.train()
    for e in range(local_ep):
        for loader in [pri_train_loader]: #pri_train_loader, pub_train_loader]:
            train_loss = 0.0
            for img,label in loader:
                #img, label = img.view(-1, mnist_dim).cuda(gpu), label.cuda(gpu)
                img, label = img.cuda(gpu), label.cuda(gpu)
                local_optimizer.zero_grad()
                output = local_model(img)
                loss = criterion(output, label)
                loss.backward()
                local_optimizer.step()
                train_loss += loss.item() * img.size(0)
            train_loss /= len(train_loader.dataset)
            print(f"Local data Global Epoch: {epoch}: Local Epoch: {e} Loss: {train_loss}")
    
    clone_model.train()        
    for e in range(local_ep):
        for loader in [pub_train_loader]: #pri_train_loader, pub_train_loader]:
            train_loss = 0.0
            for img, label in loader:
                #img, label = img.view(-1,mnist_dim).cuda(gpu), label.cuda(gpu)
                img, label = img.cuda(gpu), label.cuda(gpu)
                local_optimizer.zero_grad()
                logits = local_model(img)
                
                
                _, pred_labels = torch.max(logits, 1)
                pred_labels = pred_labels.view(-1)
    
                clone_optimizer.zero_grad()
                output = clone_model(img)
                loss = criterion(output, pred_labels)
                loss.backward()
                clone_optimizer.step()
                train_loss += loss.item() * img.size(0)
                
                pub_loss = criterion(logits, label)
                pub_loss.backward()
                local_optimizer.step()
                
            train_loss /= len(loader.dataset)
            print(f"Public data Global Epoch: {epoch}: Local Epoch: {e} Loss: {train_loss}")
        target_accs.append(test_inference(local_model, test_loader)[0])
        accs.append(test_inference(clone_model, test_loader)[0])
        errors.append(test_error(local_model, clone_model, test_loader))
                #train_loss += loss.item() * img.size(0)
            #train_loss /= len(train_loader.dataset)
            #print(f"Global data Global Epoch: {epoch}: Local Epoch: {e} Loss: {train_loss}")
# Out:
# Local data Global Epoch: 0: Local Epoch: 0 Loss: 0.015092246717217496
# Local data Global Epoch: 0: Local Epoch: 1 Loss: 0.009052237942398884
# Local data Global Epoch: 0: Local Epoch: 2 Loss: 0.0076279271520344385
# Local data Global Epoch: 0: Local Epoch: 3 Loss: 0.005927222421613624
# Local data Global Epoch: 0: Local Epoch: 4 Loss: 0.006013798220254315
# Public data Global Epoch: 0: Local Epoch: 0 Loss: 0.7290500673225806
# Public data Global Epoch: 0: Local Epoch: 1 Loss: 0.10136937259748113
# Public data Global Epoch: 0: Local Epoch: 2 Loss: 0.09052413853253737
# Public data Global Epoch: 0: Local Epoch: 3 Loss: 0.07842023397494283
# Public data Global Epoch: 0: Local Epoch: 4 Loss: 0.07475873457110885
# Local data Global Epoch: 1: Local Epoch: 0 Loss: 0.04375041678933194
# Local data Global Epoch: 1: Local Epoch: 1 Loss: 0.011385307175605461
# Local data Global Epoch: 1: Local Epoch: 2 Loss: 0.009301469010019112
# Public data Global Epoch: 12: Local Epoch: 3 Loss: 0.08287378479015005
# Public data Global Epoch: 12: Local Epoch: 4 Loss: 0.08554274628489923
# Local data Global Epoch: 13: Local Epoch: 0 Loss: 0.060704568327563976
# Local data Global Epoch: 13: Local Epoch: 1 Loss: 0.014633489084997448
# Local data Global Epoch: 13: Local Epoch: 2 Loss: 0.011457650619865483
# Local data Global Epoch: 13: Local Epoch: 3 Loss: 0.008837956379290333
# Local data Global Epoch: 13: Local Epoch: 4 Loss: 0.008036250278236665
# Public data Global Epoch: 13: Local Epoch: 0 Loss: 1.3985314556503592
# Public data Global Epoch: 13: Local Epoch: 1 Loss: 0.1390281170511715
# Public data Global Epoch: 13: Local Epoch: 2 Loss: 0.09833287590538838
# Public data Global Epoch: 13: Local Epoch: 3 Loss: 0.08677052272679502
# Public data Global Epoch: 13: Local Epoch: 4 Loss: 0.08635223403015127
# Local data Global Epoch: 14: Local Epoch: 0 Loss: 0.06544751856278165
# Local data Global Epoch: 14: Local Epoch: 1 Loss: 0.01301676705848031
# Local data Global Epoch: 14: Local Epoch: 2 Loss: 0.010420712272186515
# Local data Global Epoch: 14: Local Epoch: 3 Loss: 0.008820770021940013
# Local data Global Epoch: 14: Local Epoch: 4 Loss: 0.008445347259089414
# Public data Global Epoch: 14: Local Epoch: 0 Loss: 1.51515349014366
# Public data Global Epoch: 14: Local Epoch: 1 Loss: 0.11141549321700721
# Public data Global Epoch: 14: Local Epoch: 2 Loss: 0.08112289914813096
# Public data Global Epoch: 14: Local Epoch: 3 Loss: 0.08459470663661342
# Public data Global Epoch: 14: Local Epoch: 4 Loss: 0.08403818673492443
# Local data Global Epoch: 15: Local Epoch: 0 Loss: 0.0576740663763759
# Local data Global Epoch: 15: Local Epoch: 1 Loss: 0.012221817569388057
# Local data Global Epoch: 15: Local Epoch: 2 Loss: 0.011531101349264767
# Local data Global Epoch: 15: Local Epoch: 3 Loss: 0.010651104396229778
# Local data Global Epoch: 15: Local Epoch: 4 Loss: 0.009568530200789587
# Public data Global Epoch: 15: Local Epoch: 0 Loss: 1.4958643249603254
# Public data Global Epoch: 15: Local Epoch: 1 Loss: 0.1001842846264885
# Public data Global Epoch: 15: Local Epoch: 2 Loss: 0.08004384949990641

# %%
print(len(accs))
# Out:
# 1000

# %%
from matplotlib.pyplot import subplots
import matplotlib.pyplot as plt

# %%
print(len(accs))
x = np.arange(200)
t = ['o', 'x', 'o']
c = ['r', 'b', 'g']
legends = ['Target Model', 'Clone Model','diff']
plt.plot(x, [target_accs[i] for i in range(0,len(target_accs),5)], label=legends[0])#,marker=t[i])
plt.plot(x, [accs[i] for i in range(0,len(accs),5)], label=legends[1])#,marker=t[i])  
plt.plot(x, [errors[i] for i in range(0,len(accs),5)], label=legends[2])#,marker=t[i])  
plt.xlabel('Iterations')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, linestyle='-.', color='black')

#plt.savefig('KL_result_0.9.png')
plt.show()
# Out:
# 1000
